# %%
import pandas as pd
estabelecimentos = pd.read_csv('ubs_funcionamentonone.csv')

# %%
estabelecimentos.head()
# Out:
#    gid  co_cnes        lat       long  \
# 0   27  2105462 -15.342934 -43.670329
# 1  331  2576368 -23.598461 -51.632051
# 2  273  2478234  -3.499682 -40.277123
# 3   46  2412802 -13.277739 -41.385155
# 4  330  2756161  -7.115000 -34.863000
#
#                                          no_fantasia  \
# 0                                UAPS NOVA ESPERANCA
# 1                      UBS LAZARO DE PAULA RODRIGUES
# 2  CENTRO DE SAUDE DA FAMILIA DO MIRIM ANTONIO BI...
# 3             US DA FAMILIA DE IRACEMA COSTA E SILVA
# 4                          USF INTEGRADA SANTA CLARA
#
#                no_logradouro nu_endereco       no_bairro   nu_telefone  \
# 0     AV JOAO TEIXEIRA FILHO         566          CENTRO  (38)38331252
# 1                RUA MARUMBI         S/N          CENTRO  (43)34327398
# 2                ALTO ALEGRE         S/N     ALTO ALEGRE    8836431065
# 3  TRAVESSA ITAMAR MAGALHAES          25          CENTRO   77 34135203
# ...

# %%
campinas = estabelecimentos.loc[estabelecimentos['cidade'] == 'Campinas']

# %%
campinas = campinas.reset_index()

# %%
campinas
# Out:
#     index    gid  co_cnes        lat       long  \
# 0     550   2314  2022907 -22.871797 -47.028308
# 1    1064   2944  6032478 -22.907342 -47.060156
# 2    1261   3450  2022788 -22.907342 -47.060156
# 3    1324   3502  2022613 -22.943820 -47.097681
# 4    2069   4707  2023180 -22.922000 -47.028920
# ..    ...    ...      ...        ...        ...
# 62  36498  48030  6584772 -22.849590 -47.124400
# 63  36505  48029  6584470 -22.802240 -47.066250
# 64  36576  48031  6585159 -22.936210 -47.038610
# 65  39276  49977  7520433 -22.903390 -47.056610
# 66  39464     66  2034263 -22.909940 -47.062630
#
#                                           no_fantasia  \
# 0                    CENTRO DE SAUDE VILA 31 DE MARCO
# 1                     CENTRO DE SAUDE SATELITE IRIS I
# 2              CENTRO DE SAUDE PERSEU LEITE DE BARROS
# 3       CENTRO DE SAUDE CAMPOS ELISEOS TANCREDO NEVES
# 4   CENTRO DE SAUDE ERNESTO SIERRA HUNOVITCH OROZI...
# ..                                                ...
# ...

# %%
campinas.to_json('estabelecimentos_campinas.json', orient='index')
